# %%
#Imports and setup
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient
import asyncio
import sys
import os
from dotenv import load_dotenv

sys.path.append(os.path.abspath(".."))
load_dotenv()
# Out:
# True

# %%
#Initialize model client
model_client = OpenAIChatCompletionClient(
    model="gpt-3.5-turbo",
    # api_key="OPENAI_API_KEY",  # or rely on environment variable
)

# %%
#Define tool function
async def get_weather(city: str) -> str:
    """Get the weather for a given city."""
    return f"The weather in {city} is 73 degrees and Sunny."

# %%
#Create agent
agent = AssistantAgent(
    name="multi_agent",
    model_client=model_client,
    tools=[get_weather],
    system_message="You are a helpful assistant.",
    reflect_on_tool_use=True,
    model_client_stream=True,  # Enable streaming tokens from the model client.
)

# %%
#Run the agent (use top-level await)
await Console(agent.run_stream(task="Who is a data scientist?"))
await model_client.close()  # Close the connection to the model client
# Out:
# ---------- TextMessage (user) ----------
# Who is a data scientist?
# ---------- ModelClientStreamingChunkEvent (multi_agent) ----------
# A data scientist is a professional who analyzes and interprets complex data to help organizations make informed decisions. They use various tools and techniques to discover trends, patterns, and insights from large datasets. Data scientists have expertise in statistics, data analysis, machine learning, and programming, and they play a crucial role in extracting valuable insights from data to drive business strategies and decision-making processes.
