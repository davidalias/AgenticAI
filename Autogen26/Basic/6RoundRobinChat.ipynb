# %% [markdown]
# #Example 1

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import MaxMessageTermination
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
import os 
import sys
sys.path.append(os.path.abspath(".."))
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model_client = OpenAIChatCompletionClient(
    model="gpt-3.5-turbo"
)

# %%
agent1= AssistantAgent(
    name="Assistant1",
    system_message="You are a helpful assistant",
    model_client=model_client
)

agent2 = AssistantAgent(
    name="Assistant2",
    system_message="You are a helpful assistant",
    model_client=model_client
)

# %%
termination = MaxMessageTermination(3)
team = RoundRobinGroupChat([agent1, agent2], termination_condition=termination)

# %%
stream = team.run_stream(task="Count numbers from 1 to 10, respond one at a time")
await Console(stream)
# Out:
# ---------- TextMessage (user) ----------
# Count numbers from 1 to 10, respond one at a time
# ---------- TextMessage (Assistant1) ----------
# 1
# ---------- TextMessage (Assistant2) ----------
# 2
# TaskResult(messages=[TextMessage(id='48f4055f-7bc8-4e9e-a0bd-eea0e61f0df9', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 4, 7, 6, 26, 0, 395827, tzinfo=datetime.timezone.utc), content='Count numbers from 1 to 10, respond one at a time', type='TextMessage'), TextMessage(id='3ec52ad3-7ba1-45d5-89f1-469cffb38f32', source='Assistant1', models_usage=RequestUsage(prompt_tokens=31, completion_tokens=1), metadata={}, created_at=datetime.datetime(2026, 4, 7, 6, 26, 3, 398005, tzinfo=datetime.timezone.utc), content='1', type='TextMessage'), TextMessage(id='23cff945-0d53-43e7-b0a9-d2f9426185da', source='Assistant2', models_usage=RequestUsage(prompt_tokens=39, completion_tokens=1), metadata={}, created_at=datetime.datetime(2026, 4, 7, 6, 26, 4, 739970, tzinfo=datetime.timezone.utc), content='2', type='TextMessage')], stop_reason='Maximum number of messages 3 reached, current message count: 3')

# %% [markdown]
# #Example2

# %%
stream = team.run_stream(task="Tell me some jokes")
await Console(stream)
# Out:
# ---------- TextMessage (user) ----------
# Tell me some jokes
# ---------- TextMessage (Assistant1) ----------
# Sure! Here's one for you: Why don't scientists trust atoms? Because they make up everything!
# ---------- TextMessage (Assistant2) ----------
# Here's another one: Why did the tomato turn red? Because it saw the salad dressing!
# TaskResult(messages=[TextMessage(id='fee9b462-3009-4362-b2b3-72cd3ce0731c', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 4, 7, 6, 30, 37, 957774, tzinfo=datetime.timezone.utc), content='Tell me some jokes', type='TextMessage'), TextMessage(id='6c1d2bf0-4970-4a02-bb87-03b18dd59169', source='Assistant1', models_usage=RequestUsage(prompt_tokens=53, completion_tokens=21), metadata={}, created_at=datetime.datetime(2026, 4, 7, 6, 30, 40, 24124, tzinfo=datetime.timezone.utc), content="Sure! Here's one for you: Why don't scientists trust atoms? Because they make up everything!", type='TextMessage'), TextMessage(id='3ae23bd8-e1fc-431a-b471-10aa537c51e5', source='Assistant2', models_usage=RequestUsage(prompt_tokens=81, completion_tokens=19), metadata={}, created_at=datetime.datetime(2026, 4, 7, 6, 30, 40, 766305, tzinfo=datetime.timezone.utc), content="Here's another one: Why did the tomato turn red? Because it saw the salad dressing!", type='TextMessage')], stop_reason='Maximum number of messages 3 reached, current message count: 3')
