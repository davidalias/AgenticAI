# %% [markdown]
# Data Ingestion

# %%
# document structure
from langchain_core.documents import Document

# %%
doc =  Document(
    page_content="this is the main text content I am using to create RAG",
    metadata = {
        "source": "example.txt",
        "pages": 1,
        "author":"KN",
        "date_created":"2025-10-13"
    }
)

# %%
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'KN', 'date_created': '2025-10-13'}, page_content='this is the main text content I am using to create RAG')

# %%
# create a txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/intro.txt" : """
    Python Programming is a high-level, interpreted language known for its simplicity, 
    and first released in 1991.  
    """,
    "../data/text_files/machine_learning.txt": """
    ML is a subset of AI that enble systems to learn and improve from experience
    without being explicitly programmed. It focuses on developing computer programs that can access data and 
    use it to learn for themselves
    """
}

# %%
# if no files, the following files will create the text files

for filepath, content in sample_texts.items():
    with open(filepath,"w",encoding="utf-8") as f:
        f.write(content)

print("Sample text files created!")
# Out:
# Sample text files created!

# %%
#TextLoader
from langchain.document_loaders import TextLoader
#from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("../data/text_files/intro.txt", encoding="utf-8")
loader

# %%
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/intro.txt'}, page_content='\n    Python Programming is a high-level, interpreted language known for its simplicity, \n    and first released in 1991.  \n    ')]

# %%
#Directory Loader
from langchain_community.document_loaders import DirectoryLoader

#load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", #Pattern to match files
    loader_cls= TextLoader, #Loader class to use
    loader_kwargs={"encoding":"utf-8"},
    show_progress=False
)

# %%
documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\intro.txt'}, page_content='\n    Python Programming is a high-level, interpreted language known for its simplicity, \n    and first released in 1991.  \n    '),
#  Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='\n    ML is a subset of AI that enble systems to learn and improve from experience\n    without being explicitly programmed. It focuses on developing computer programs that can access data and \n    use it to learn for themselves\n    ')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

#load all pdf files form the directory
dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", #pattern to match files
    loader_cls=PyMuPDFLoader, #loader class to use
    #loader_kwargs={"encoding":"utf-8"},
    show_progress=False
)

# %%
pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-10-14T12:30:02+05:30', 'source': '..\\data\\pdf\\test.pdf', 'file_path': '..\\data\\pdf\\test.pdf', 'total_pages': 1, 'format': 'PDF 1.7', 'title': '', 'author': 'Davis Boban', 'subject': '', 'keywords': '', 'moddate': '2025-10-14T12:30:02+05:30', 'trapped': '', 'modDate': "D:20251014123002+05'30'", 'creationDate': "D:20251014123002+05'30'", 'page': 0}, page_content='Agentic AI refers to artificial intelligence systems that exhibit agency—meaning they \ncan autonomously pursue goals, make decisions, and take actions in dynamic \nenvironments, often with minimal human intervention. These systems go beyond \nreactive behavior and are designed to be proactive, adaptive, and goal-directed. \nKey Characteristics of Agentic AI: \n1. Autonomy: Operates independently, making decisions without constant human \ninput. \n2. Goal-Oriented Behavior: Pursues sp
# ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
